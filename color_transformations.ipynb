# %%
import os
from PIL import Image

def change_brightness(img: Image.Image, level: float) -> Image.Image:
    def brightness(c: int) -> float:
        return 128 + level + (c - 128)

    if not -255.0 <= level <= 255.0:
        raise ValueError("level must be between -255.0 (black) and 255.0 (white)")
    return img.point(brightness)

# %%
# creating validation image sets with various brightness levels between -200 and 200, going in increments of 50

# brightness -200

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_200_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = -200

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness -150

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_150_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = -150

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness -100

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_100_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = -100

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness -50

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_50_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = -50

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness 0

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_0_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = 0

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness 50

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_50_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = 50

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness 100

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_100_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = 100

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness 150

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_150_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = 150

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# brightness 200

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_200_bright"

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Brightness level
    level = 200

    # Iterate through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                bright_img = change_brightness(img, level)
                bright_img.save(output_path)

# %%
import os
from PIL import Image


def change_contrast(img: Image.Image, level: int) -> Image.Image:
    """
    Change contrast of an image using the given level.
    Level should be between -255 (low contrast) to +255 (high contrast).
    """
    factor = (259 * (level + 255)) / (255 * (259 - level))

    def contrast(c: int) -> int:
        return int(128 + factor * (c - 128))

    return img.point(contrast)

# %%
# creating validation image sets with various contrast levels between -200 and 200, going in increments of 50

# contrast -200

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_200_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, -200)  # You can adjust the level here
                contrast_img.save(output_path)

# contrast -150

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_150_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, -150)  # You can adjust the level here
                contrast_img.save(output_path)

# contrast -100

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_100_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, -100)  # You can adjust the level here
                contrast_img.save(output_path)

# contrast -50

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_50_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, -50)  # You can adjust the level here
                contrast_img.save(output_path)

# contrast 0

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_0_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, 0)  # You can adjust the level here
                contrast_img.save(output_path)

# contrast 50

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_50_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, 50)  # You can adjust the level here
                contrast_img.save(output_path)

# contrast 100

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_100_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, 100)  # You can adjust the level here
                contrast_img.save(output_path)


# contrast 150

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_150_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, 150)  # You can adjust the level here
                contrast_img.save(output_path)


# contrast 200

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_200_contrast"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                contrast_img = change_contrast(img, 200)  # You can adjust the level here
                contrast_img.save(output_path)

# %%
import os
from PIL import Image, ImageEnhance

def change_saturation(img: Image.Image, factor: float) -> Image.Image:
    """
    Change saturation of a PIL Image.
    factor > 1.0 increases saturation
    factor = 1.0 leaves it unchanged
    factor < 1.0 decreases saturation
    """
    enhancer = ImageEnhance.Color(img)
    return enhancer.enhance(factor)

# %%
# saturation changes

# -2

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_2_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=-2)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)

# -1.5

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_15_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=-1.5)
                saturated_img.save(output_path)

# -1

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_1_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=-1)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)


# -0.5

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_neg_05_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=-0.5)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)

# 0

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_0_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=0)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)

# 0.5

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_05_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=0.5)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)

# 1

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_1_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=1)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)

# 1.5

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_15_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=1.5)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)

# 2

if __name__ == "__main__":
    input_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images"
    output_dir = "/Users/charlotteimbert/Documents/SP2025/NEUR189B/tiny-imagenet-200/val/images_2_saturation"

    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".JPEG") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            with Image.open(input_path) as img:
                saturated_img = change_saturation(img, factor=2)  # 1.8 = 80% more saturated
                saturated_img.save(output_path)
